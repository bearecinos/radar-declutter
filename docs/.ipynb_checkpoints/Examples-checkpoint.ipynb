# %% [markdown]
# This notebook demonstrates how to use the declutter module. The arguments differ for some of the methods for each step in order to show the range of available options. For information about the options for each method, see the wiki at https://gitlab.data.bas.ac.uk/dboyle/radar-declutter/wikis.

# %%
import os
import shutil
# %matplotlib inline

# %% [markdown]
# ## Load a raster from arcMap
#
# These steps convert the raster 'database/ML_DEM_merged.tif' to the file 'maps.hdf5'. The raster is in a polar stereographic coordinate system so is first projected to a UTM zone, and the arguments indicate that it should be resampled to a 10m cell size.
#
# The output directory is set as 'database' so that the projected and resampled rasters are saved there rather than in the current directory.

# %%
from declutter import makeArrays

# %%
# Method 1
# 78.9 and 12.0 are latitude and longitude for the grid to enable projection
makeArrays.makeAll('database/ML_DEM_merged.tif', 78.9, 12.0, 10.0, 'database')
# Out:
# Resampling to a cell size of 10.0
# Projecting to UTM coordinate system.
# 0

# %%
# Method 2 - may be needed for very large rasters causing MemoryError when working with all three at once.
# These can be run in any order.
makeArrays.justAspect('database/ML_DEM_merged.tif', 78.9, 12.0, 10.0, 'database')
makeArrays.justSlope('database/ML_DEM_merged.tif', 78.9, 12.0, 10.0, 'database')
makeArrays.justHeightmap('database/ML_DEM_merged.tif', 78.9, 12.0, 10.0, 'database')

# %%
# Method 3 - command line instruction (! is jupyter magic to indicate command line)
! python -m declutter load database/ML_DEM_merged.tif 78.9 12.0 -c 10.0 -o database

# %% [markdown]
# ## Change radargram range/granularity
#
# Set the duration the radargram should listen for and how frequently to sample the response. Internally only the timestep and total number of steps are stored, although methods to work with distance are provided too. See the wiki for which commands overwrite others.

# %%
# Method 1
from declutter.modelling import parameters
parameters.setTimeStep(1e-8)
parameters.setSpaceStep(1.5) # equivalent ignoring floating point precision errors
parameters.setSteps(1200)

# %%
! python -m declutter config --maxdist 3000.0 --dx 2.0

# to show the current settings
python -m declutter config --show

# %% [markdown]
# ## Directly display a radargram
#
# Having created 'maps.hdf5' in the previous step, it is now possible to generate a radargram from the path file 'sparsePath.gpx'.
# Most of the time is spent generating the data to work with, and applying a model to this data is then fast by comparison. Therefore, if several changes to the model want to be tested, it is possible to store the data generated. Each change to models.py can then be compared much faster.

# %%
from declutter import fullModel, path, radar

# %%
# Method 1 - Data generated per point not saved, radargram not saved
data = fullModel.processData('demoData/sparsePath.gpx', save = False)
# Out:
# 100% (27 of 27) |#############################################| Time: 1:31
# array([[[ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#           0.00000000e+000,  0.00000000e+000,  0.00000000e+000],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#           1.53743171e-001,  2.29254591e-001,  3.19996392e-001],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -1.00531094e+000, -4.09369909e-001,  1.41923821e-001],
#         ...,
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -1.18230582e-218, -6.57318110e-222, -3.45637684e-225],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -7.34126077e-003, -3.55573358e-003, -1.62293560e-003],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -5.57019724e-001, -3.51690014e-001, -1.70038402e-001]],
#
#        [[ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#           0.00000000e+000,  0.00000000e+000,  0.00000000e+000],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#           5.83696549e-002,  8.80937031e-002,  1.24002805e-001],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -9.09954191e-001, -5.02028393e-001, -1.59060246e-001],
#         ...,
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -2.06901150e-220, -1.14985102e-223, -6.04406218e-227],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -1.10086112e-003, -5.26914033e-004, -2.37649793e-004],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -3.63834829e-001, -2.14432443e-001, -1.04944808e-001]],
#
#        [[ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#           1.36702473e+000,  1.44227487e+000,  1.51384680e+000],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -1.59431100e+000, -1.01329827e+000, -3.92693057e-001],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#           1.86319842e+000,  2.77191783e+000,  3.69500934e+000],
#         ...,
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -8.81014317e-001, -4.15830425e-001,  2.97724249e-001],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -1.32434235e+000, -1.52310134e+000, -1.67193778e+000],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -2.87046637e-001,  1.12153008e-001,  6.59706323e-001]],
#
#        [[ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#           1.04148887e-001,  1.23296052e-001,  1.45840051e-001],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -3.48084893e-001, -1.28074248e-001,  1.03783318e-001],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -1.34604092e-001,  5.60765994e-001,  1.25542990e+000],
#         ...,
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -2.59867952e-001, -9.48953855e-002,  1.46069099e-001],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -5.59886337e-001, -6.46218549e-001, -7.01647889e-001],
#         [ 0.00000000e+000,  0.00000000e+000,  0.00000000e+000, ...,
#          -1.00722709e+000, -7.89786605e-001, -5.16499020e-001]]])

# %%
# Method 2 - Data generated per point is saved, radargram saved
path.processData('demoData/sparsePath.gpx',outName = 'demoData/points')
data = radar.compare('demoData/points',save = 'demoData/figure')

# %%
# %%capture result # hides output of command, remove to show result.
# Method 3 - Command line
! python -m declutter model demoData/sparsePath.gpx -f -o demoData/points -s demoData/figure

# %% [markdown]
# ## Display a radargram from existing point files
#
# If the option was selected to store .hdf5 files for each point in the previous step ('demoData/points', created by methods 2 or 3), the radargram can now be quickly displayed.

# %%
from declutter import radar
# Method 1
data = radar.compare('demoData/points')
# Out:
# 100% (27 of 27) |#############################################| Time: 0:07

# %%
# %%capture result # hides output of command, remove to show result.
# Method 2
# !! python -m declutter display demoData/points

# %% [markdown]
# ## Single point trace
#
# The output of the model for a single point can also be shown.

# %%
from declutter import models
from declutter.modelling import backscatter
models.wiggle('demoData/points/point15.hdf5', intensityModel = backscatter.specular2Model)

# %% [markdown]
# ## Command line help
#
# The cell below displays the help info for each of the command line options.

# %%
divider = '\n\n'+'-'*80+'\n\n'
! python -m declutter -h

print divider

! python -m declutter load -h

print divider

! python -m declutter model -h

print divider

! python -m declutter display -h
# Out:
# usage: python -m declutter [-h] {load,model,display} ...
#
# optional arguments:
#   -h, --help            show this help message and exit
#
# subcommands:
#   Select one of the commands listed below. Use '<command> -h' to display
#   help for that particular command. For more detailed instructions, see the
#   gitlab page https://gitlab.data.bas.ac.uk/dboyle/radar-
#   declutter/wikis/Contents
#
#   {load,model,display}
#     load                Loads a raster into numpy arrays.
#     model               Displays the radargram for a path.
#     display             Displays a radargram from existing point data.
#
#
# --------------------------------------------------------------------------------
#
#
# usage: python -m declutter load [-h] [-c CELLSIZE] [-o OUT]
#                                 filename latitude longitude
#
# Takes a raster and generates the slope and aspect of the surface, saving all
# three these along with the original raster in 'maps.hdf5'. The raster will be
# projected if a coordinate system other than UTM is used and the raster can
# also be changed to use a cell size which is a multiple of the original.
#
# positional arguments:
#   filename              Name of the raster file to load.
#   latitude              Latitude of the region, used to determine UTM zone for
#                         projection.
#   longitude             Longitude of the region, used to determine UTM zone
#                         for projection.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -c CELLSIZE, --cellSize CELLSIZE
#                         Allows the raster to be stored with a larger cell size
#                         than the original.
#   -o OUT, --out OUT     Specifies a directory to store the raster in if it is
#                         resampled or projected.
#
#
# --------------------------------------------------------------------------------
#
#
# usage: python -m declutter model [-h] [-t {gpx,dst,xyz}] [--start START]
#                                  [--end END] [-f] [-o OUT] [-n | -s SAVE]
#                                  filename
#
# Assuming 'maps.hdf5' exists in the current directory, this takes a series of
# points and generates an estimate of the radargram expected.
#
# positional arguments:
#   filename              Name of the path file to load.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -t {gpx,dst,xyz}, --type {gpx,dst,xyz}
#                         Specifies the file type, one of 'gpx', 'dst' or 'xyz'.
#                         This is identified by the file extension if not given.
#   --start START         Can specify how many points to ignore from the start
#                         of the path.
#   --end END             Can specify how many points to ignore from the end of
#                         the path.
#   -f, --files           Store the intermediate data generated for each point.
#   -o OUT, --out OUT     Specifies the directory to store the intermediate
#                         point data in.
#   -n, --no              Do not save the radargram produced, but still displays
#                         it.
#   -s SAVE, --save SAVE  The name to save the radargram as.
#
#
# --------------------------------------------------------------------------------
#
#
# usage: python -m declutter display [-h] [-a] [-n | -s SAVE] directory
#
# Assuming 'maps.hdf5' exists in the current directory, this takes a directory
# of point data and generates an estimate of the radargram expected.
#
# positional arguments:
#   directory             Name of the directory containing the point data.
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -a, --adjusted        Aligns points of equal elevation on the radargram
#                         rather than time.
#   -n, --no              Do not save the radargram produced, but still displays
#                         it.
#   -s SAVE, --save SAVE  The name to save the radargram as.
